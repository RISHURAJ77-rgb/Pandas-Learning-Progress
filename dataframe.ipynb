# %%
import numpy as np
import pandas as pd

# %%
data={
    'Name':['john','Aman','Peter','Linda'],
    'Age':[23,34,45,56],
    'city':['new york','paris','london','berlin'],
    'salary':[2000,3000,5000,600]
}
d=pd.DataFrame(data)

# %%
d
# Out:
#     Name  Age      city  salary
# 0   john   23  new york    2000
# 1   Aman   34     paris    3000
# 2  Peter   45    london    5000
# 3  Linda   56    berlin     600

# %%
data=[
    ['john','Aman','Peter','Linda'],
    [23,34,45,56],
    ['new york','paris','london','berlin'],
    [2000,3000,5000,600]
]
row=['name','age','city','salary']
d2=pd.DataFrame(data)
d2=pd.DataFrame(data,row)

# %%
d2
# Out:
#                0      1       2       3
# name        john   Aman   Peter   Linda
# age           23     34      45      56
# city    new york  paris  london  berlin
# salary      2000   3000    5000     600

# %%
d2.loc['name']
# Out:
# 0     john
# 1     Aman
# 2    Peter
# 3    Linda
# Name: name, dtype: object

# %%
data_list=[
['john',20,'new york',6500],
['anna',28,'paris',3456],
['peter',34,'berlin',62000],
['linda',42,'london',84000]
]
d3=pd.DataFrame(data_list)
column=['name','age','city','salary']
d3=pd.DataFrame(data_list,columns=column)

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3['name']
# Out:
# 0     john
# 1     anna
# 2    peter
# 3    linda
# Name: name, dtype: str

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3["Designation"]=["doctor","eng","doc","ram"]

# %%
d3
# Out:
#     name  age      city  salary Designation
# 0   john   20  new york    6500      doctor
# 1   anna   28     paris    3456         eng
# 2  peter   34    berlin   62000         doc
# 3  linda   42    london   84000         ram

# %%
d3.drop('Designation',axis=1,inplace=True)

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3.loc[[0,1]]
# Out:
#    name  age      city  salary
# 0  john   20  new york    6500
# 1  anna   28     paris    3456

# %%
d3.iloc[0]
# Out:
# name          john
# age             20
# city      new york
# salary        6500
# Name: 0, dtype: object

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3.loc[[0,1]][["city","salary"]]
# Out:
#        city  salary
# 0  new york    6500
# 1     paris    3456

# %%
d3.loc[[2,3]][["name","age"]]
# Out:
#     name  age
# 2  peter   34
# 3  linda   42

# %%
d3
# Out:
#     name  age      city  salary
# 0   john   20  new york    6500
# 1   anna   28     paris    3456
# 2  peter   34    berlin   62000
# 3  linda   42    london   84000

# %%
d3[(d3["age"]>30) & (d3["city"]=="london")]
# Out:
#     name  age    city  salary
# 3  linda   42  london   84000
